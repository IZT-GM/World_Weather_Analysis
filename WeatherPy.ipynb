# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations
lats=np.random.uniform(low=-90, high=90, size=1500)
lngs=np.random.uniform(low=-180, high=180, size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
from citipy import citipy

# %%
# #create a list for holding the cities
# cities=[]
# #identify the nearest city for each latitude and longitude combination
# for coordinate in coordinates:
#     city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
#     #if the city is unique, then we will add it to the cities list
#     if city not in cities:
#         cities.append(city)
# #print the city count to confirm sufficient count
# len(cities)
# Out:
# 628

# %%
# # Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# #create an empty list to hold the weather data
# city_data=[]
# #print the begining of the logging
# print('Beginning Data Retrieval    ')
# print('----------------------------')

# #create counters
# record_count=1
# set_count=1

# #loop through all the cities in our list
# for i, city in enumerate(cities):
#     #group cities in sets of 50 for logging purposes
#     if (i % 50 == 0 and i>=50):
#         set_count+=1
#         record_count=1
#     #Create endpoint URL with each city
#     city_url=url+'&q='+city.replace(" ","+")
#     #Log tje URL, record, and set numbers and the city
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     #Add 1 to the record count
#     record_count+=1
    
#     #rUN API request for each of the cities
#     try:
#         city_weather=requests.get(city_url).json()
#         city_lat=city_weather['coord']['lat']
#         city_lng=city_weather['coord']['lon']
#         city_max_temp=city_weather['main']['temp_max']
#         city_humidity=city_weather['main']['humidity']
#         city_clouds=city_weather['clouds']['all']
#         city_wind=city_weather['wind']['speed']
#         city_country=city_weather['sys']['country']
#         #convert data to ISO standard
#         city_date=datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
#         #append the city
#         city_data.append({'City':city.title(),
#                          'Lat':city_lat,
#                          'Lng':city_lng,
#                          'Max Temp':city_max_temp,
#                          'Humidity':city_humidity,
#                          'Cloudiness':city_clouds,
#                          'Wind Speed':city_wind,
#                          'Country':city_country,
#                          'Date':city_date})
# #If an error is experienced, skip the city
#     except:
#         print(f"City not found. Skipping...")
#         pass

# #Indicate that data loading is complete
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | awjilah
# Processing Record 4 of Set 1 | north myrtle beach
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | fairbanks
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | pierre
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | ahmadpur sial
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | bonavista
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | krasnogorodsk
# Processing Record 27 of Set 1 | praia da vitoria
# Processing Record 28 of Set 1 | ypsonas
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | tierralta
# Processing Record 38 of Set 1 | sao jose de ribamar
# Processing Record 39 of Set 1 | dunedin
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | cabo san lucas
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | cabedelo
# Processing Record 1 of Set 2 | novyy urengoy
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | binga
# Processing Record 4 of Set 2 | vao
# Processing Record 5 of Set 2 | kuloy
# Processing Record 6 of Set 2 | mnogovershinnyy
# Processing Record 7 of Set 2 | awbari
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | kutum
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | muskogee
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | mangaratiba
# Processing Record 18 of Set 2 | carbondale
# Processing Record 19 of Set 2 | itarema
# Processing Record 20 of Set 2 | robat karim
# Processing Record 21 of Set 2 | mount gambier
# Processing Record 22 of Set 2 | chimore
# Processing Record 23 of Set 2 | plettenberg bay
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | ararangua
# Processing Record 26 of Set 2 | payo
# Processing Record 27 of Set 2 | katobu
# Processing Record 28 of Set 2 | kolpashevo
# Processing Record 29 of Set 2 | bloemfontein
# Processing Record 30 of Set 2 | havoysund
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | sibolga
# Processing Record 35 of Set 2 | sangar
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | a
# City not found. Skipping...
# Processing Record 38 of Set 2 | yumen
# Processing Record 39 of Set 2 | tari
# Processing Record 40 of Set 2 | bijie
# Processing Record 41 of Set 2 | mitsamiouli
# Processing Record 42 of Set 2 | palmer
# Processing Record 43 of Set 2 | rantepao
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | ormara
# Processing Record 46 of Set 2 | dawei
# Processing Record 47 of Set 2 | pasni
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | kota belud
# Processing Record 50 of Set 2 | vanimo
# Processing Record 1 of Set 3 | khani
# Processing Record 2 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | andapa
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | muroto
# Processing Record 9 of Set 3 | bathurst
# Processing Record 10 of Set 3 | perpignan
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | vardo
# Processing Record 13 of Set 3 | aklavik
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | onokhoy
# Processing Record 17 of Set 3 | arandis
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | lewistown
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | senno
# Processing Record 22 of Set 3 | korla
# Processing Record 23 of Set 3 | arlit
# Processing Record 24 of Set 3 | gat
# Processing Record 25 of Set 3 | acapulco
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | yar-sale
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | la suiza
# Processing Record 30 of Set 3 | alausi
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | kamina
# Processing Record 33 of Set 3 | nedryhayliv
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | amboasary
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | gravelbourg
# Processing Record 39 of Set 3 | arman
# Processing Record 40 of Set 3 | faya
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | emerald
# Processing Record 43 of Set 3 | sayanogorsk
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | shingu
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | constantine
# Processing Record 48 of Set 3 | te anau
# Processing Record 49 of Set 3 | avera
# Processing Record 50 of Set 3 | vilcun
# Processing Record 1 of Set 4 | nizwa
# Processing Record 2 of Set 4 | paita
# Processing Record 3 of Set 4 | ibra
# Processing Record 4 of Set 4 | cururupu
# Processing Record 5 of Set 4 | monkey hill
# Processing Record 6 of Set 4 | fountain
# Processing Record 7 of Set 4 | chara
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | svetlyy
# Processing Record 10 of Set 4 | batticaloa
# Processing Record 11 of Set 4 | paamiut
# Processing Record 12 of Set 4 | soe
# Processing Record 13 of Set 4 | kalmunai
# Processing Record 14 of Set 4 | mandalgovi
# Processing Record 15 of Set 4 | lufilufi
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | waseca
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | pailon
# Processing Record 20 of Set 4 | krasne
# Processing Record 21 of Set 4 | kandava
# Processing Record 22 of Set 4 | oranjemund
# Processing Record 23 of Set 4 | sitka
# Processing Record 24 of Set 4 | santa cruz
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | komsomolskiy
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | erzin
# Processing Record 31 of Set 4 | sao felix do xingu
# Processing Record 32 of Set 4 | maykor
# Processing Record 33 of Set 4 | zhigansk
# Processing Record 34 of Set 4 | krasnoselkup
# Processing Record 35 of Set 4 | bone
# Processing Record 36 of Set 4 | uzhur
# Processing Record 37 of Set 4 | paralimni
# Processing Record 38 of Set 4 | lucea
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | benito juarez
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | portland
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | juneau
# Processing Record 46 of Set 4 | anuradhapura
# Processing Record 47 of Set 4 | impfondo
# Processing Record 48 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | macusani
# Processing Record 2 of Set 5 | lithakia
# Processing Record 3 of Set 5 | bezhanitsy
# Processing Record 4 of Set 5 | port macquarie
# Processing Record 5 of Set 5 | port-gentil
# Processing Record 6 of Set 5 | catamarca
# Processing Record 7 of Set 5 | virginia beach
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | thurso
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | calbuco
# Processing Record 12 of Set 5 | ola
# Processing Record 13 of Set 5 | oranjestad
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | bafoulabe
# Processing Record 16 of Set 5 | fatikchhari
# City not found. Skipping...
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | vangaindrano
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | skjervoy
# Processing Record 21 of Set 5 | mandera
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | pangai
# Processing Record 24 of Set 5 | bethel
# Processing Record 25 of Set 5 | ulaangom
# Processing Record 26 of Set 5 | mana
# Processing Record 27 of Set 5 | canguaretama
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | victor harbor
# Processing Record 30 of Set 5 | chitral
# Processing Record 31 of Set 5 | moffat
# Processing Record 32 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 5 | buala
# Processing Record 34 of Set 5 | marsaxlokk
# Processing Record 35 of Set 5 | homer
# Processing Record 36 of Set 5 | maridi
# Processing Record 37 of Set 5 | alice springs
# Processing Record 38 of Set 5 | pundaguitan
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | magugu
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | denpasar
# Processing Record 44 of Set 5 | gogrial
# Processing Record 45 of Set 5 | maryville
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | kavieng
# Processing Record 48 of Set 5 | victoria
# Processing Record 49 of Set 5 | santa ana
# Processing Record 50 of Set 5 | altea
# Processing Record 1 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 6 | wadi musa
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | padang
# Processing Record 5 of Set 6 | guaruja
# Processing Record 6 of Set 6 | mount isa
# Processing Record 7 of Set 6 | port lincoln
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | vestmanna
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | huaicheng
# Processing Record 12 of Set 6 | airai
# Processing Record 13 of Set 6 | markova
# Processing Record 14 of Set 6 | navalcarnero
# Processing Record 15 of Set 6 | launceston
# Processing Record 16 of Set 6 | slonim
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | bredasdorp
# Processing Record 19 of Set 6 | gien
# Processing Record 20 of Set 6 | biak
# Processing Record 21 of Set 6 | leningradskiy
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | bandar-e lengeh
# Processing Record 24 of Set 6 | katsuura
# Processing Record 25 of Set 6 | naryan-mar
# Processing Record 26 of Set 6 | saint joseph
# Processing Record 27 of Set 6 | tabou
# Processing Record 28 of Set 6 | mananjary
# Processing Record 29 of Set 6 | ninghai
# Processing Record 30 of Set 6 | kokopo
# Processing Record 31 of Set 6 | sinnamary
# Processing Record 32 of Set 6 | caravelas
# Processing Record 33 of Set 6 | roald
# Processing Record 34 of Set 6 | bansang
# Processing Record 35 of Set 6 | saldanha
# Processing Record 36 of Set 6 | placido de castro
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | honiara
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | abu road
# Processing Record 41 of Set 6 | shache
# Processing Record 42 of Set 6 | itaituba
# Processing Record 43 of Set 6 | phan thong
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | pavlovskaya sloboda
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | pringsewu
# Processing Record 49 of Set 6 | miraflores
# Processing Record 50 of Set 6 | puerto escondido
# Processing Record 1 of Set 7 | barvinkove
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | kendari
# Processing Record 5 of Set 7 | lerwick
# Processing Record 6 of Set 7 | beberibe
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | torbay
# Processing Record 9 of Set 7 | hambantota
# Processing Record 10 of Set 7 | grootfontein
# Processing Record 11 of Set 7 | beloha
# Processing Record 12 of Set 7 | narragansett
# Processing Record 13 of Set 7 | krasyukovskaya
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | valleyview
# Processing Record 16 of Set 7 | thinadhoo
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | deputatskiy
# Processing Record 19 of Set 7 | saint-philippe
# Processing Record 20 of Set 7 | kollam
# Processing Record 21 of Set 7 | alta floresta
# Processing Record 22 of Set 7 | balabac
# Processing Record 23 of Set 7 | bontang
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 7 | farah
# Processing Record 27 of Set 7 | mudon
# Processing Record 28 of Set 7 | changli
# Processing Record 29 of Set 7 | san quintin
# Processing Record 30 of Set 7 | nesebar
# Processing Record 31 of Set 7 | ancud
# Processing Record 32 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 7 | atambua
# Processing Record 34 of Set 7 | karaton
# Processing Record 35 of Set 7 | vaitape
# Processing Record 36 of Set 7 | murray bridge
# Processing Record 37 of Set 7 | esperance
# Processing Record 38 of Set 7 | galveston
# Processing Record 39 of Set 7 | pontianak
# Processing Record 40 of Set 7 | matara
# Processing Record 41 of Set 7 | santa maria
# Processing Record 42 of Set 7 | port hawkesbury
# Processing Record 43 of Set 7 | bambanglipuro
# Processing Record 44 of Set 7 | chiredzi
# Processing Record 45 of Set 7 | mocuba
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | merauke
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | moctezuma
# Processing Record 50 of Set 7 | sur
# Processing Record 1 of Set 8 | coihaique
# Processing Record 2 of Set 8 | boende
# Processing Record 3 of Set 8 | grand-lahou
# Processing Record 4 of Set 8 | boden
# Processing Record 5 of Set 8 | cascais
# Processing Record 6 of Set 8 | banamba
# Processing Record 7 of Set 8 | tadine
# Processing Record 8 of Set 8 | jijiga
# Processing Record 9 of Set 8 | muros
# Processing Record 10 of Set 8 | kirillov
# Processing Record 11 of Set 8 | abha
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | san vito al tagliamento
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | balkanabat
# Processing Record 16 of Set 8 | martapura
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | aripuana
# Processing Record 19 of Set 8 | mogadishu
# Processing Record 20 of Set 8 | glendive
# Processing Record 21 of Set 8 | esqueda
# Processing Record 22 of Set 8 | omsukchan
# Processing Record 23 of Set 8 | smithers
# Processing Record 24 of Set 8 | zilina
# Processing Record 25 of Set 8 | santiago
# Processing Record 26 of Set 8 | cartagena
# Processing Record 27 of Set 8 | likasi
# Processing Record 28 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 8 | duverge
# Processing Record 30 of Set 8 | manggar
# Processing Record 31 of Set 8 | cizre
# Processing Record 32 of Set 8 | halkirk
# Processing Record 33 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 8 | pacific grove
# Processing Record 35 of Set 8 | villafranca di verona
# Processing Record 36 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 8 | shenjiamen
# Processing Record 38 of Set 8 | wajima
# Processing Record 39 of Set 8 | quatre cocos
# Processing Record 40 of Set 8 | yangambi
# Processing Record 41 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | vanavara
# Processing Record 44 of Set 8 | havre-saint-pierre
# Processing Record 45 of Set 8 | kirakira
# Processing Record 46 of Set 8 | palana
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | jiexiu
# Processing Record 49 of Set 8 | filadelfia
# Processing Record 50 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | tolaga bay
# Processing Record 2 of Set 9 | tahta
# Processing Record 3 of Set 9 | flinders
# Processing Record 4 of Set 9 | kamenka
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | edd
# Processing Record 7 of Set 9 | constitucion
# Processing Record 8 of Set 9 | beidao
# Processing Record 9 of Set 9 | khatassy
# Processing Record 10 of Set 9 | yaan
# Processing Record 11 of Set 9 | warri
# Processing Record 12 of Set 9 | kristiansund
# Processing Record 13 of Set 9 | krasnyy chikoy
# Processing Record 14 of Set 9 | genhe
# Processing Record 15 of Set 9 | fukue
# Processing Record 16 of Set 9 | san cristobal
# Processing Record 17 of Set 9 | nanortalik
# Processing Record 18 of Set 9 | eidsvag
# Processing Record 19 of Set 9 | bratsk
# Processing Record 20 of Set 9 | kyzyl-suu
# Processing Record 21 of Set 9 | ixtapa
# Processing Record 22 of Set 9 | mlowo
# Processing Record 23 of Set 9 | wuda
# Processing Record 24 of Set 9 | athni
# Processing Record 25 of Set 9 | qaqortoq
# Processing Record 26 of Set 9 | tostamaa
# City not found. Skipping...
# Processing Record 27 of Set 9 | loiza
# Processing Record 28 of Set 9 | san isidro
# Processing Record 29 of Set 9 | lavrentiya
# Processing Record 30 of Set 9 | missoula
# Processing Record 31 of Set 9 | beyneu
# Processing Record 32 of Set 9 | knysna
# Processing Record 33 of Set 9 | vikulovo
# Processing Record 34 of Set 9 | sagay
# Processing Record 35 of Set 9 | jumla
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | lar
# Processing Record 38 of Set 9 | punta cardon
# Processing Record 39 of Set 9 | clarence town
# Processing Record 40 of Set 9 | port moresby
# Processing Record 41 of Set 9 | hofn
# Processing Record 42 of Set 9 | ardatov
# Processing Record 43 of Set 9 | anloga
# Processing Record 44 of Set 9 | salinas
# Processing Record 45 of Set 9 | cockburn town
# Processing Record 46 of Set 9 | belyy yar
# Processing Record 47 of Set 9 | viedma
# Processing Record 48 of Set 9 | fort morgan
# Processing Record 49 of Set 9 | guadalupe y calvo
# Processing Record 50 of Set 9 | klaksvik
# Processing Record 1 of Set 10 | camopi
# Processing Record 2 of Set 10 | anjad
# Processing Record 3 of Set 10 | anse-bertrand
# Processing Record 4 of Set 10 | hollister
# Processing Record 5 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 10 | duzici
# City not found. Skipping...
# Processing Record 7 of Set 10 | porto murtinho
# Processing Record 8 of Set 10 | bethany
# Processing Record 9 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 10 | clovis
# Processing Record 11 of Set 10 | kharitonovo
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | dekar
# Processing Record 14 of Set 10 | lubao
# Processing Record 15 of Set 10 | brae
# Processing Record 16 of Set 10 | kostomuksha
# Processing Record 17 of Set 10 | traverse city
# Processing Record 18 of Set 10 | toora-khem
# Processing Record 19 of Set 10 | ilhabela
# Processing Record 20 of Set 10 | ginir
# Processing Record 21 of Set 10 | eichstatt
# Processing Record 22 of Set 10 | mont-dore
# Processing Record 23 of Set 10 | jesup
# Processing Record 24 of Set 10 | khovu-aksy
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | xichang
# Processing Record 27 of Set 10 | jalingo
# Processing Record 28 of Set 10 | raudeberg
# Processing Record 29 of Set 10 | kununurra
# Processing Record 30 of Set 10 | malmesbury
# Processing Record 31 of Set 10 | marshalltown
# Processing Record 32 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 10 | makakilo city
# Processing Record 34 of Set 10 | manjacaze
# Processing Record 35 of Set 10 | alberton
# Processing Record 36 of Set 10 | chiang khong
# Processing Record 37 of Set 10 | pangnirtung
# Processing Record 38 of Set 10 | arkhonskaya
# Processing Record 39 of Set 10 | kousseri
# Processing Record 40 of Set 10 | lasa
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | vila velha
# Processing Record 43 of Set 10 | ampanihy
# Processing Record 44 of Set 10 | vestmannaeyjar
# Processing Record 45 of Set 10 | balykshi
# City not found. Skipping...
# Processing Record 46 of Set 10 | haimen
# Processing Record 47 of Set 10 | ucluelet
# Processing Record 48 of Set 10 | baoning
# Processing Record 49 of Set 10 | evensk
# Processing Record 50 of Set 10 | tilichiki
# Processing Record 1 of Set 11 | karlstad
# Processing Record 2 of Set 11 | saint-pierre
# Processing Record 3 of Set 11 | shimoda
# Processing Record 4 of Set 11 | fort abbas
# Processing Record 5 of Set 11 | nome
# Processing Record 6 of Set 11 | culebra
# Processing Record 7 of Set 11 | nelson bay
# Processing Record 8 of Set 11 | chardara
# Processing Record 9 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 11 | pingliang
# Processing Record 11 of Set 11 | japura
# Processing Record 12 of Set 11 | cayenne
# Processing Record 13 of Set 11 | ciudad bolivar
# Processing Record 14 of Set 11 | seoul
# Processing Record 15 of Set 11 | oriximina
# Processing Record 16 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 11 | petropavl
# Processing Record 18 of Set 11 | chaman
# Processing Record 19 of Set 11 | leirvik
# Processing Record 20 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 11 | flin flon
# Processing Record 22 of Set 11 | comodoro rivadavia
# Processing Record 23 of Set 11 | uthal
# Processing Record 24 of Set 11 | thai binh
# Processing Record 25 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 11 | rudsar
# Processing Record 27 of Set 11 | san sebastian
# Processing Record 28 of Set 11 | the valley
# Processing Record 29 of Set 11 | necochea
# Processing Record 30 of Set 11 | amla
# Processing Record 31 of Set 11 | easton
# Processing Record 32 of Set 11 | ndola
# Processing Record 33 of Set 11 | kotelnikovo
# Processing Record 34 of Set 11 | pouebo
# Processing Record 35 of Set 11 | belyye berega
# Processing Record 36 of Set 11 | kurgan
# Processing Record 37 of Set 11 | ranghulu
# Processing Record 38 of Set 11 | puerto baquerizo moreno
# Processing Record 39 of Set 11 | benicarlo
# Processing Record 40 of Set 11 | najran
# Processing Record 41 of Set 11 | terrace
# Processing Record 42 of Set 11 | maumere
# Processing Record 43 of Set 11 | yeltsovka
# City not found. Skipping...
# Processing Record 44 of Set 11 | mahibadhoo
# Processing Record 45 of Set 11 | benton harbor
# Processing Record 46 of Set 11 | preobrazheniye
# Processing Record 47 of Set 11 | sesimbra
# Processing Record 48 of Set 11 | knittelfeld
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 50 of Set 11 | kaitangata
# Processing Record 1 of Set 12 | shaunavon
# Processing Record 2 of Set 12 | egvekinot
# Processing Record 3 of Set 12 | maunabo
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | sioux lookout
# Processing Record 6 of Set 12 | tangjiazhuang
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | ulaanbaatar
# Processing Record 9 of Set 12 | baker
# Processing Record 10 of Set 12 | guilin
# Processing Record 11 of Set 12 | wawa
# Processing Record 12 of Set 12 | teknaf
# Processing Record 13 of Set 12 | coari
# Processing Record 14 of Set 12 | kinsale
# Processing Record 15 of Set 12 | prince rupert
# Processing Record 16 of Set 12 | ustka
# Processing Record 17 of Set 12 | burns lake
# Processing Record 18 of Set 12 | shenkursk
# Processing Record 19 of Set 12 | campechuela
# Processing Record 20 of Set 12 | batak
# Processing Record 21 of Set 12 | edendale
# Processing Record 22 of Set 12 | iranshahr
# Processing Record 23 of Set 12 | kenai
# Processing Record 24 of Set 12 | moussoro
# Processing Record 25 of Set 12 | riyadh
# Processing Record 26 of Set 12 | lac du bonnet
# Processing Record 27 of Set 12 | maniwaki
# Processing Record 28 of Set 12 | ruteng
# Processing Record 29 of Set 12 | kuytun
# Processing Record 30 of Set 12 | harper
# Processing Record 31 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 12 | dawlatabad
# Processing Record 33 of Set 12 | iwanai
# Processing Record 34 of Set 12 | abu samrah
# Processing Record 35 of Set 12 | khuzhir
# Processing Record 36 of Set 12 | urubicha
# Processing Record 37 of Set 12 | erenhot
# Processing Record 38 of Set 12 | shetpe
# Processing Record 39 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 12 | samarai
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | witu
# Processing Record 43 of Set 12 | belonia
# Processing Record 44 of Set 12 | wielun
# Processing Record 45 of Set 12 | ust-ishim
# Processing Record 46 of Set 12 | dinguiraye
# Processing Record 47 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 12 | mayo
# Processing Record 49 of Set 12 | stephenville
# Processing Record 50 of Set 12 | teya
# Processing Record 1 of Set 13 | rumford
# Processing Record 2 of Set 13 | adre
# Processing Record 3 of Set 13 | bolgatanga
# Processing Record 4 of Set 13 | slave lake
# Processing Record 5 of Set 13 | nizhniy kuranakh
# Processing Record 6 of Set 13 | bhanpuri
# Processing Record 7 of Set 13 | ternate
# Processing Record 8 of Set 13 | daloa
# Processing Record 9 of Set 13 | udachnyy
# Processing Record 10 of Set 13 | kouroussa
# Processing Record 11 of Set 13 | los llanos de aridane
# Processing Record 12 of Set 13 | berlevag
# Processing Record 13 of Set 13 | chapais
# Processing Record 14 of Set 13 | sanchursk
# Processing Record 15 of Set 13 | yekaterinoslavka
# Processing Record 16 of Set 13 | la ronge
# Processing Record 17 of Set 13 | akalkot
# Processing Record 18 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 13 | yatou
# Processing Record 20 of Set 13 | rawlins
# Processing Record 21 of Set 13 | seddon
# Processing Record 22 of Set 13 | nantucket
# Processing Record 23 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 13 | dikson
# Processing Record 26 of Set 13 | tiznit
# Processing Record 27 of Set 13 | skibbereen
# Processing Record 28 of Set 13 | mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             Fortuna  40.60 -124.16     57.00       100           1
# 1              Broome  42.25  -75.83     73.00        88          90
# 2             Awjilah  29.11   21.29     60.03        66           1
# 3  North Myrtle Beach  33.82  -78.68     77.00        94          90
# 4              Hobart -42.88  147.33     66.20        45          75
# 5           Fairbanks  64.84 -147.72     66.20        45          90
# 6        Saint George  37.10 -113.58     91.40        13           1
# 7        Ponta Do Sol  32.67  -17.10     64.40        77          20
# 8                Lata  40.16   -8.33     68.00        89           0
# 9             Ushuaia -54.80  -68.30     42.80        79          40
#
#    Wind Speed Country                 Date
# 0        8.05      US  2020-05-29 04:20:50
# 1       11.41      US  2020-05-29 04:21:19
# 2       10.20      LY  2020-05-29 04:21:20
# 3       11.41      US  2020-05-29 04:17:30
# 4       19.46      AU  2020-05-29 04:20:18
# 5        3.36      US  2020-05-29 04:17:42
# 6        4.70      US  2020-05-29 04:20:59
# 7        1.12      PT  2020-05-29 04:21:20
# 8        3.40      PT  2020-05-29 04:21:20
# 9       18.34      AR  2020-05-29 04:18:48

# %%
column_order=['City','Country','Date','Lat','Lng','Max Temp','Humidity',
             'Cloudiness','Wind Speed']
city_data_df=city_data_df[column_order]
city_data_df.head(10)
# Out:
#                  City Country                 Date    Lat     Lng  Max Temp  \
# 0             Fortuna      US  2020-05-29 04:20:50  40.60 -124.16     57.00
# 1              Broome      US  2020-05-29 04:21:19  42.25  -75.83     73.00
# 2             Awjilah      LY  2020-05-29 04:21:20  29.11   21.29     60.03
# 3  North Myrtle Beach      US  2020-05-29 04:17:30  33.82  -78.68     77.00
# 4              Hobart      AU  2020-05-29 04:20:18 -42.88  147.33     66.20
# 5           Fairbanks      US  2020-05-29 04:17:42  64.84 -147.72     66.20
# 6        Saint George      US  2020-05-29 04:20:59  37.10 -113.58     91.40
# 7        Ponta Do Sol      PT  2020-05-29 04:21:20  32.67  -17.10     64.40
# 8                Lata      PT  2020-05-29 04:21:20  40.16   -8.33     68.00
# 9             Ushuaia      AR  2020-05-29 04:18:48 -54.80  -68.30     42.80
#
#    Humidity  Cloudiness  Wind Speed
# 0       100           1        8.05
# 1        88          90       11.41
# 2        66           1       10.20
# 3        94          90       11.41
# 4        45          75       19.46
# 5        45          90        3.36
# 6        13           1        4.70
# 7        77          20        1.12
# 8        89           0        3.40
# 9        79          40       18.34

# %%
# Create the output file (CSV).
output_data_file='weather_data/cities.csv'
# Export the City_data into a CSV
city_data_df.to_csv(output_data_file,index_label='City_ID')

# %%
# Extract relevant fields from the DataFrame for plotting.
lats=city_data_df['Lat']
max_temps=city_data_df['Max Temp']
humidity=city_data_df['Humidity']
cloudiness=city_data_df['Cloudiness']
wind_speed=city_data_df['Wind Speed']

# %%
#import time module
import time
#Get today's date in seconds
today=time.strftime('%x')
today
# Out:
# '05/29/20'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor='k', linewidths=1,marker='o',
           alpha=0.8,label='Cities')

#incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.yticks(np.arange(10,110,step=10))

#save the figure
plt.savefig('weather_data/Fig1.png')

#Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. Humidity.
plt.scatter(lats,
           humidity,
           edgecolor='k', linewidths=1,marker='o',
           alpha=0.8,label='Cities')

#incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)
plt.yticks(np.arange(0,110,step=10))

#save the figure
plt.savefig('weather_data/Fig2.png')

#Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. Cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolor='k', linewidths=1,marker='o',
           alpha=0.8,label='Cities')

#incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)
plt.yticks(np.arange(0,110,step=10))

#save the figure
plt.savefig('weather_data/Fig3.png')

#Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. Wind Speed.
plt.scatter(lats,
           wind_speed,
           edgecolor='k', linewidths=1,marker='o',
           alpha=0.8,label='Cities')

#incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
# plt.yticks(np.arange(0,110,step=10))

#save the figure
plt.savefig('weather_data/Fig4.png')

#Show plot
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values,y_values, title, y_label, text_coordinates):
    
    # Perform linear regression.
    (slope,intercept,r_value,p_value,std_err)=linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept. 
    regress_values=x_values*slope+intercept

    # Get the equation of the line.
    line_eq='y = '+str(round(slope,2))+' x + '+str(round(intercept,2))

    # Create a scatter plot of the x and y values.
    plt.scatter(x_values,y_values)

    # Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
    plt.plot(x_values, regress_values,'r')

    # Annotate the text for the line equation and add its coordinates.
    plt.annotate(line_eq,text_coordinates, fontsize=15, color='red')
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
#create northen and southern hesmisphere dataFrame
northern_hemi_df=city_data_df.loc[(city_data_df['Lat']>=0)]
southern_hemi_df=city_data_df.loc[(city_data_df['Lat']<0)]

# %%
#Linear regression on the Northern Hemisphere - Max Tempeature
x_values=northern_hemi_df['Lat']
y_values=northern_hemi_df['Max Temp']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\n for Maximum Temperature',
                       'Max Temp', (5,40))

# %%
#Linear regression on the Southern Hemisphere - Max Tempeature
x_values=southern_hemi_df['Lat']
y_values=southern_hemi_df['Max Temp']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\n for Maximum Temperature',
                       'Max Temp', (-50,85))

# %%
# %matplotlib inline
#Linear regression on the Northern Hemisphere - % Humidity
x_values=northern_hemi_df['Lat']
y_values=northern_hemi_df['Humidity']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\n for % Humidity',
                       '% Humidity', (45,13))

# %%
#Linear regression on the Southern Hemisphere - Humidity
x_values=southern_hemi_df['Lat']
y_values=southern_hemi_df['Humidity']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\n for % Humidity',
                       '% Humidity', (-53,20))

# %%
#Linear regression on the Northern Hemisphere - % Cloudiness
x_values=northern_hemi_df['Lat']
y_values=northern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\n for % Cloudiness',
                       '% Cloudiness', (20,44.3))

# %%
#Linear regression on the Southern Hemisphere -  % Cloudiness
x_values=southern_hemi_df['Lat']
y_values=southern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\n for % Cloudiness',
                       '% Cloudiness', (-55,57))

# %%
#Linear regression on the Northern Hemisphere - Wind Speed
x_values=northern_hemi_df['Lat']
y_values=northern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\n for Wind Speed',
                       'Wind Speed', (20,30))

# %%
#Linear regression on the Southern Hemisphere -  Wind Speed
x_values=southern_hemi_df['Lat']
y_values=southern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\n for Wind Speed',
                       'Wind Speed', (-40,20))
